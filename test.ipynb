# %%
"""Basic connection example.
"""

import redis

r = redis.Redis(
    host='drop-cattle-incandescent-58044.db.redis.io',
    port=13023,
    decode_responses=True,
    username="default",
    password="Rh40yg64UV1la5fqq0MwgQkZepGEQ1EW",
)

success = r.set('foo', 'bar')
# True

result = r.get('foo')
print(result)
# >>> bar
# Out:
# bar
